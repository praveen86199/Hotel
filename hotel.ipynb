# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

# %%
df= pd.read_csv("C:/Users/MMC/Desktop/excel files/hotel_bookings.csv", encoding="unicode escape")
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
median_children = df['children'].median()
df['children'].fillna(median_children, inplace=True)
df
# Out:
# C:\Users\MMC\AppData\Local\Temp\ipykernel_12808\4181219348.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['children'].fillna(median_children, inplace=True)
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# ...

# %%
mode_country = df['country'].mode()[0]
df['country'].fillna(mode_country, inplace=True)
df
# Out:
# C:\Users\MMC\AppData\Local\Temp\ipykernel_12808\2414053070.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna(mode_country, inplace=True)
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# ...

# %%
m=df["agent"].mode()[0]
m 
df["agent"].fillna(m,inplace=True)
df
# Out:
# C:\Users\MMC\AppData\Local\Temp\ipykernel_12808\1436205245.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["agent"].fillna(m,inplace=True)
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# ...

# %%
m=df["company"].mode()[0]
m
df["company"].fillna(m,inplace=True)
df
# Out:
# C:\Users\MMC\AppData\Local\Temp\ipykernel_12808\3562280017.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["company"].fillna(m,inplace=True)
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Length: 119390, dtype: bool

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# # peak months

# %%
sns.countplot(x="arrival_date_month" ,data=df,palette="crest")
plt.xticks(rotation=99)
plt.show()
# Out:
# C:\Users\MMC\AppData\Local\Temp\ipykernel_12808\97855923.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="arrival_date_month" ,data=df,palette="crest")

# %% [markdown]
# # how many days tourist stay in week

# %%
total_nights = df['stays_in_weekend_nights'] + df['stays_in_week_nights']
total_nights
# Out:
# 0         0
# 1         0
# 2         1
# 3         1
# 4         2
#          ..
# 119385    7
# 119386    7
# 119387    7
# 119388    7
# 119389    9
# Length: 119390, dtype: int64

# %% [markdown]
# # cancel  deposite

# %%
sns.countplot(x="deposit_type" ,data=df,palette="crest",hue="hotel")
plt.xticks(rotation=99)
plt.show()

# %% [markdown]
# # reservation_status

# %%
sns.countplot(x="hotel" ,data=df,palette="magma",hue="reservation_status")
plt.xticks(rotation=99)
plt.show()

# %% [markdown]
# # hotel count

# %%
gb=df.groupby("country").agg({"hotel":"count"})
gb
# Out:
#          hotel
# country
# ABW          2
# AGO        362
# AIA          1
# ALB         12
# AND          7
# ...        ...
# VGB          1
# VNM          8
# ZAF         80
# ZMB          2
# ZWE          4
#
# [177 rows x 1 columns]

# %% [markdown]
# # days_in_waiting_list

# %%
gb=df.groupby("hotel").agg({"days_in_waiting_list":"count"})
gb
# Out:
#               days_in_waiting_list
# hotel
# City Hotel                   79330
# Resort Hotel                 40060

# %%
sns.barplot(x = gb.index, y = gb["days_in_waiting_list"], data = gb, palette = "flare")
plt.show()
# Out:
# C:\Users\MMC\AppData\Local\Temp\ipykernel_12808\3667455819.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = gb.index, y = gb["days_in_waiting_list"], data = gb, palette = "flare")

# %% [markdown]
# # Analyze the distribution of assigned room types to understand which types of rooms are most commonly assigned to guests.

# %%
sns.countplot(x="assigned_room_type" ,data=df,palette="cubehelix",hue="reservation_status")
plt.xticks(rotation=99)
plt.show()

# %%
sns.barplot(x ="customer_type", y = "adults", data = df, palette = "flare")
plt.show()
# Out:
# C:\Users\MMC\AppData\Local\Temp\ipykernel_12808\3681897204.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x ="customer_type", y = "adults", data = df, palette = "flare")

# %%
total_adults = df['adults'].sum()
total_children = df['children'].sum()
total_babies = df['babies'].sum()

tot={"adult":total_adults,'Children': total_children, 'Babies': total_babies}
tot
# Out:
# {'adult': 221636, 'Children': 12403.0, 'Babies': 949}

# %% [markdown]
# #  Hotel Reservation

# %%
sns.countplot(x= "hotel", hue="is_canceled" ,data = df, palette="flare")
plt.show()

# %% [markdown]
# # reserve Room

# %%
gb=df.groupby("hotel").agg({"reserved_room_type":"count"})
gb
# Out:
#               reserved_room_type
# hotel
# City Hotel                 79330
# Resort Hotel               40060

# %%
ex=[ 0,0.1]
plt.pie(gb["reserved_room_type"],labels=gb.index,explode=ex,shadow=True)
plt.show()

# %% [markdown]
# # Markekt Segmemnt

# %%
sns.countplot(x="market_segment",hue="hotel",data=df)
plt.xticks(rotation=99)
plt.show()

# %%
sns.countplot(x="required_car_parking_spaces",hue="hotel",data=df)
plt.xticks(rotation=99)
plt.show()

# %% [markdown]
# # average_revenue_by_deposit

# %%
average_revenue_by_deposit = df.groupby('deposit_type')["adr"].mean()
average_revenue_by_deposit
# Out:
# deposit_type
# No Deposit    103.525067
# Non Refund     89.964017
# Refundable     76.209753
# Name: adr, dtype: float64

# %% [markdown]
# # Repeated Guest

# %%
gb=df.groupby("hotel").agg({"is_repeated_guest":"count"})
gb
# Out:
#               is_repeated_guest
# hotel
# City Hotel                79330
# Resort Hotel              40060

# %%
plt.bar(gb.index,gb["is_repeated_guest"],color="#CF8778")
plt.show()

# %% [markdown]
#  # Privious Booking Not Cancel

# %%
gb=df.groupby("hotel").agg({"previous_bookings_not_canceled":"count"})
gb
# Out:
#               previous_bookings_not_canceled
# hotel
# City Hotel                             79330
# Resort Hotel                           40060
